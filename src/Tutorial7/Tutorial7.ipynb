# %% [markdown]
# # Tutorial 7: ARGA & ARVGA
#
# Paper:
# * [Adversarially Regularized Graph Autoencoder for Graph Embedding](https://www.ijcai.org/Proceedings/2018/0362.pdf)
#
# Code:
#  * [ARGA & ARVGA](https://pytorch-geometric.readthedocs.io/en/latest/_modules/torch_geometric/nn/models/autoencoder.html)
#  * [Example on clustering](https://github.com/rusty1s/pytorch_geometric/blob/master/examples/argva_node_clustering.py)

# %%
import os
import torch

os.environ['TORCH'] = torch.__version__
print(torch.__version__)
# Out:
# 2.3.1+cu121

# %% [markdown]
# ## Imports

# %%
import os.path as osp
import torch
import torch.nn.functional as F
from sklearn.cluster import KMeans
from sklearn.metrics.cluster import (
    v_measure_score,
    homogeneity_score,
    completeness_score,
)
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import torch_geometric.transforms as T
from torch_geometric.datasets import Planetoid
from torch_geometric.nn import GCNConv
from torch_geometric.nn.models.autoencoder import ARGVA
from torch_geometric.utils import train_test_split_edges

# %%
use_cuda = False

# %% [markdown]
# ## Define the dataset

# %% [markdown]
# Download the dataset

# %%
dataset = 'Cora'
path = osp.join('.', 'data', dataset)
dataset = Planetoid(path, dataset, transform=T.NormalizeFeatures())
data = dataset.get(0)
# Out:
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.x
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.tx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.allx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.y
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ty
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ally
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.graph
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.test.index
# Processing...
# Done!

# %% [markdown]
# Get the number of nodes

# %%
num_nodes = data.x.shape[0]

# %% [markdown]
# Create the train/val/test data

# %%
data.train_mask = data.val_mask = data.test_mask = None
data = train_test_split_edges(data)
data
# Out:
# /home/kklepikov/_code_/PytorchGeometricTutorial/.venv/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'train_test_split_edges' is deprecated, use 'transforms.RandomLinkSplit' instead
#   warnings.warn(out)
# Data(x=[2708, 1433], y=[2708], val_pos_edge_index=[2, 263], test_pos_edge_index=[2, 527], train_pos_edge_index=[2, 8976], train_neg_adj_mask=[2708, 2708], val_neg_edge_index=[2, 263], test_neg_edge_index=[2, 527])

# %% [markdown]
# ## Define the model

# %% [markdown]
# Define the encoder classes (the same as in `Tutorial 6`)

# %%
class VEncoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super(VEncoder, self).__init__()
        self.conv1 = GCNConv(in_channels, 2 * out_channels, cached=True)
        self.conv_mu = GCNConv(2 * out_channels, out_channels, cached=True)
        self.conv_logstd = GCNConv(2 * out_channels, out_channels, cached=True)

    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index))
        return self.conv_mu(x, edge_index), self.conv_logstd(x, edge_index)

# %% [markdown]
# Define the discriminator class

# %%
class Discriminator(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super(Discriminator, self).__init__()
        self.lin1 = torch.nn.Linear(in_channels, hidden_channels)
        self.lin2 = torch.nn.Linear(hidden_channels, hidden_channels)
        self.lin3 = torch.nn.Linear(hidden_channels, out_channels)

    def forward(self, x):
        x = F.relu(self.lin1(x))
        x = F.relu(self.lin2(x))
        x = self.lin3(x)
        return x

# %% [markdown]
# Define the training algorithm

# %%
def train():
    model.train()
    encoder_optimizer.zero_grad()

    z = model.encode(data.x, data.train_pos_edge_index)

    for i in range(5):
        idx = range(num_nodes)
        discriminator.train()
        discriminator_optimizer.zero_grad()
        discriminator_loss = model.discriminator_loss(z[idx])   # Comment
        discriminator_loss.backward(retain_graph=True)
        discriminator_optimizer.step()

    loss = 0
    loss = loss + model.reg_loss(z)  # Comment

    loss = loss + model.recon_loss(z, data.train_pos_edge_index)
    loss = loss + (1 / data.num_nodes) * model.kl_loss()
    loss.backward()

    encoder_optimizer.step()

    return loss

# %% [markdown]
# Define a training test method

# %%
@torch.no_grad()
def test():
    model.eval()
    z = model.encode(data.x, data.train_pos_edge_index)

    # Cluster embedded values using k-means.
    kmeans_input = z.cpu().numpy()
    kmeans = KMeans(n_clusters=7, random_state=0).fit(kmeans_input)
    pred = kmeans.predict(kmeans_input)

    labels = data.y.cpu().numpy()
    completeness = completeness_score(labels, pred)
    hm = homogeneity_score(labels, pred)
    nmi = v_measure_score(labels, pred)

    auc, ap = model.test(z, data.test_pos_edge_index, data.test_neg_edge_index)

    return auc, ap, completeness, hm, nmi

# %% [markdown]
# ## Initialize the model

# %% [markdown]
# Initialize an encoder and a discriminator

# %%
latent_size = 32
encoder = VEncoder(data.num_features, out_channels=latent_size)

discriminator = Discriminator(
    in_channels=latent_size, hidden_channels=64, out_channels=1
)   # Comment

# %% [markdown]
# Initialize the model and move everything to the GPU

# %%
model = ARGVA(encoder, discriminator)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model, data = model.to(device), data.to(device)

# %% [markdown]
# Define the optimizers

# %%
discriminator_optimizer = torch.optim.Adam(discriminator.parameters(), lr=0.001)
encoder_optimizer = torch.optim.Adam(encoder.parameters(), lr=0.005)

# %% [markdown]
# ### Train the model

# %%
for epoch in range(1, 201):
    loss = train()
    auc, ap, completeness, hm, nmi = test()
    print(
        f'Epoch: {epoch:03d}, Loss: {loss:.3f}, AUC: {auc:.3f}, '
        f'AP: {ap:.3f}, Completeness: {completeness:.3f}, '
        f'Homogeneity: {hm:.3f}, NMI: {nmi:.3f}'
    )
# Out:
# Epoch: 001, Loss: 5.476, AUC: 0.693, AP: 0.705, Completeness: 0.061, Homogeneity: 0.059, NMI: 0.060
# Epoch: 002, Loss: 4.561, AUC: 0.685, AP: 0.703, Completeness: 0.057, Homogeneity: 0.055, NMI: 0.056
# Epoch: 003, Loss: 4.041, AUC: 0.683, AP: 0.703, Completeness: 0.055, Homogeneity: 0.054, NMI: 0.055
# Epoch: 004, Loss: 3.656, AUC: 0.688, AP: 0.707, Completeness: 0.062, Homogeneity: 0.059, NMI: 0.060
# Epoch: 005, Loss: 3.114, AUC: 0.699, AP: 0.717, Completeness: 0.090, Homogeneity: 0.088, NMI: 0.089
# Epoch: 006, Loss: 2.827, AUC: 0.715, AP: 0.731, Completeness: 0.106, Homogeneity: 0.103, NMI: 0.104
# Epoch: 007, Loss: 2.465, AUC: 0.724, AP: 0.742, Completeness: 0.139, Homogeneity: 0.130, NMI: 0.134
# Epoch: 008, Loss: 2.270, AUC: 0.721, AP: 0.741, Completeness: 0.170, Homogeneity: 0.164, NMI: 0.167
# Epoch: 009, Loss: 2.173, AUC: 0.716, AP: 0.735, Completeness: 0.172, Homogeneity: 0.169, NMI: 0.171
# Epoch: 010, Loss: 2.159, AUC: 0.722, AP: 0.739, Completeness: 0.171, Homogeneity: 0.163, NMI: 0.167
# Epoch: 011, Loss: 2.165, AUC: 0.731, AP: 0.748, Completeness: 0.218, Homogeneity: 0.209, NMI: 0.213
# Epoch: 012, Loss: 2.162, AUC: 0.745, AP: 0.760, Completeness: 0.230, Homogeneity: 0.223, NMI: 0.226
# Epoch: 013, Loss: 2.174, AUC: 0.760, AP: 0.770, Completeness: 0.243, Homogeneity: 0.238, NMI: 0.240
# Epoch: 014, Loss: 2.171, AUC: 0.766, AP: 0.773, Completeness: 0.251, Homogeneity: 0.244, NMI: 0.247
# Epoch: 015, Loss: 2.211, AUC: 0.766, AP: 0.772, Completeness: 0.272, Homogeneity: 0.260, NMI: 0.266
# Epoch: 016, Loss: 2.291, AUC: 0.773, AP: 0.777, Completeness: 0.275, Homogeneity: 0.261, NMI: 0.268
# Epoch: 017, Loss: 2.394, AUC: 0.786, AP: 0.789, Completeness: 0.287, Homogeneity: 0.278, NMI: 0.282
# Epoch: 018, Loss: 2.495, AUC: 0.802, AP: 0.804, Completeness: 0.300, Homogeneity: 0.290, NMI: 0.295
# Epoch: 019, Loss: 2.566, AUC: 0.818, AP: 0.818, Completeness: 0.316, Homogeneity: 0.305, NMI: 0.310
# Epoch: 020, Loss: 2.616, AUC: 0.825, AP: 0.823, Completeness: 0.334, Homogeneity: 0.324, NMI: 0.329
# Epoch: 021, Loss: 2.646, AUC: 0.819, AP: 0.818, Completeness: 0.314, Homogeneity: 0.300, NMI: 0.307
# Epoch: 022, Loss: 2.731, AUC: 0.813, AP: 0.813, Completeness: 0.334, Homogeneity: 0.330, NMI: 0.332
# Epoch: 023, Loss: 2.912, AUC: 0.818, AP: 0.817, Completeness: 0.341, Homogeneity: 0.340, NMI: 0.340
# Epoch: 024, Loss: 3.109, AUC: 0.832, AP: 0.828, Completeness: 0.335, Homogeneity: 0.326, NMI: 0.330
# Epoch: 025, Loss: 3.229, AUC: 0.840, AP: 0.832, Completeness: 0.347, Homogeneity: 0.350, NMI: 0.349
# Epoch: 026, Loss: 3.257, AUC: 0.841, AP: 0.829, Completeness: 0.342, Homogeneity: 0.330, NMI: 0.335
# Epoch: 027, Loss: 3.324, AUC: 0.843, AP: 0.829, Completeness: 0.357, Homogeneity: 0.361, NMI: 0.359
# Epoch: 028, Loss: 3.356, AUC: 0.849, AP: 0.833, Completeness: 0.362, Homogeneity: 0.365, NMI: 0.363
# Epoch: 029, Loss: 3.397, AUC: 0.854, AP: 0.838, Completeness: 0.393, Homogeneity: 0.383, NMI: 0.388
# Epoch: 030, Loss: 3.468, AUC: 0.858, AP: 0.842, Completeness: 0.374, Homogeneity: 0.361, NMI: 0.368
# Epoch: 031, Loss: 3.507, AUC: 0.859, AP: 0.844, Completeness: 0.364, Homogeneity: 0.369, NMI: 0.367
# Epoch: 032, Loss: 3.607, AUC: 0.859, AP: 0.846, Completeness: 0.379, Homogeneity: 0.389, NMI: 0.384
# Epoch: 033, Loss: 3.747, AUC: 0.857, AP: 0.845, Completeness: 0.397, Homogeneity: 0.392, NMI: 0.394
# Epoch: 034, Loss: 3.895, AUC: 0.853, AP: 0.843, Completeness: 0.431, Homogeneity: 0.436, NMI: 0.434
# Epoch: 035, Loss: 4.080, AUC: 0.850, AP: 0.840, Completeness: 0.407, Homogeneity: 0.402, NMI: 0.405
# Epoch: 036, Loss: 4.177, AUC: 0.847, AP: 0.837, Completeness: 0.410, Homogeneity: 0.405, NMI: 0.407
# Epoch: 037, Loss: 4.237, AUC: 0.845, AP: 0.837, Completeness: 0.454, Homogeneity: 0.418, NMI: 0.435
# Epoch: 038, Loss: 4.334, AUC: 0.847, AP: 0.838, Completeness: 0.454, Homogeneity: 0.419, NMI: 0.436
# Epoch: 039, Loss: 4.398, AUC: 0.849, AP: 0.839, Completeness: 0.392, Homogeneity: 0.387, NMI: 0.389
# Epoch: 040, Loss: 4.485, AUC: 0.850, AP: 0.842, Completeness: 0.384, Homogeneity: 0.391, NMI: 0.387
# Epoch: 041, Loss: 4.495, AUC: 0.849, AP: 0.843, Completeness: 0.401, Homogeneity: 0.400, NMI: 0.400
# Epoch: 042, Loss: 4.621, AUC: 0.849, AP: 0.844, Completeness: 0.401, Homogeneity: 0.399, NMI: 0.400
# Epoch: 043, Loss: 4.638, AUC: 0.849, AP: 0.844, Completeness: 0.382, Homogeneity: 0.383, NMI: 0.382
# Epoch: 044, Loss: 4.670, AUC: 0.850, AP: 0.844, Completeness: 0.370, Homogeneity: 0.346, NMI: 0.357
# Epoch: 045, Loss: 4.742, AUC: 0.852, AP: 0.843, Completeness: 0.349, Homogeneity: 0.349, NMI: 0.349
# Epoch: 046, Loss: 4.638, AUC: 0.854, AP: 0.843, Completeness: 0.356, Homogeneity: 0.343, NMI: 0.350
# Epoch: 047, Loss: 4.648, AUC: 0.854, AP: 0.843, Completeness: 0.334, Homogeneity: 0.325, NMI: 0.330
# Epoch: 048, Loss: 4.603, AUC: 0.853, AP: 0.842, Completeness: 0.333, Homogeneity: 0.327, NMI: 0.330
# Epoch: 049, Loss: 4.497, AUC: 0.848, AP: 0.839, Completeness: 0.325, Homogeneity: 0.320, NMI: 0.322
# Epoch: 050, Loss: 4.347, AUC: 0.842, AP: 0.834, Completeness: 0.331, Homogeneity: 0.327, NMI: 0.329
# Epoch: 051, Loss: 4.402, AUC: 0.835, AP: 0.829, Completeness: 0.315, Homogeneity: 0.324, NMI: 0.319
# Epoch: 052, Loss: 4.338, AUC: 0.830, AP: 0.825, Completeness: 0.325, Homogeneity: 0.321, NMI: 0.323
# Epoch: 053, Loss: 4.201, AUC: 0.828, AP: 0.823, Completeness: 0.303, Homogeneity: 0.312, NMI: 0.308
# Epoch: 054, Loss: 4.137, AUC: 0.830, AP: 0.825, Completeness: 0.320, Homogeneity: 0.314, NMI: 0.317
# Epoch: 055, Loss: 4.137, AUC: 0.836, AP: 0.830, Completeness: 0.316, Homogeneity: 0.311, NMI: 0.313
# Epoch: 056, Loss: 4.000, AUC: 0.844, AP: 0.836, Completeness: 0.321, Homogeneity: 0.317, NMI: 0.319
# Epoch: 057, Loss: 4.052, AUC: 0.853, AP: 0.842, Completeness: 0.325, Homogeneity: 0.323, NMI: 0.324
# Epoch: 058, Loss: 3.925, AUC: 0.860, AP: 0.847, Completeness: 0.323, Homogeneity: 0.328, NMI: 0.326
# Epoch: 059, Loss: 3.922, AUC: 0.864, AP: 0.848, Completeness: 0.352, Homogeneity: 0.326, NMI: 0.339
# Epoch: 060, Loss: 3.836, AUC: 0.864, AP: 0.847, Completeness: 0.347, Homogeneity: 0.354, NMI: 0.350
# Epoch: 061, Loss: 3.812, AUC: 0.864, AP: 0.847, Completeness: 0.352, Homogeneity: 0.343, NMI: 0.347
# Epoch: 062, Loss: 3.833, AUC: 0.866, AP: 0.850, Completeness: 0.349, Homogeneity: 0.342, NMI: 0.345
# Epoch: 063, Loss: 3.733, AUC: 0.867, AP: 0.855, Completeness: 0.337, Homogeneity: 0.324, NMI: 0.330
# Epoch: 064, Loss: 3.759, AUC: 0.868, AP: 0.859, Completeness: 0.322, Homogeneity: 0.324, NMI: 0.323
# Epoch: 065, Loss: 3.773, AUC: 0.870, AP: 0.862, Completeness: 0.339, Homogeneity: 0.335, NMI: 0.337
# Epoch: 066, Loss: 3.809, AUC: 0.872, AP: 0.865, Completeness: 0.324, Homogeneity: 0.323, NMI: 0.323
# Epoch: 067, Loss: 3.791, AUC: 0.874, AP: 0.867, Completeness: 0.332, Homogeneity: 0.336, NMI: 0.334
# Epoch: 068, Loss: 3.834, AUC: 0.876, AP: 0.869, Completeness: 0.339, Homogeneity: 0.328, NMI: 0.333
# Epoch: 069, Loss: 3.769, AUC: 0.878, AP: 0.870, Completeness: 0.339, Homogeneity: 0.347, NMI: 0.343
# Epoch: 070, Loss: 3.833, AUC: 0.879, AP: 0.871, Completeness: 0.343, Homogeneity: 0.351, NMI: 0.347
# Epoch: 071, Loss: 3.844, AUC: 0.880, AP: 0.873, Completeness: 0.343, Homogeneity: 0.352, NMI: 0.347
# Epoch: 072, Loss: 3.884, AUC: 0.881, AP: 0.874, Completeness: 0.323, Homogeneity: 0.337, NMI: 0.330
# Epoch: 073, Loss: 3.971, AUC: 0.882, AP: 0.876, Completeness: 0.364, Homogeneity: 0.367, NMI: 0.366
# Epoch: 074, Loss: 3.995, AUC: 0.884, AP: 0.877, Completeness: 0.357, Homogeneity: 0.368, NMI: 0.363
# Epoch: 075, Loss: 4.073, AUC: 0.885, AP: 0.878, Completeness: 0.337, Homogeneity: 0.338, NMI: 0.337
# Epoch: 076, Loss: 4.109, AUC: 0.886, AP: 0.880, Completeness: 0.380, Homogeneity: 0.381, NMI: 0.380
# Epoch: 077, Loss: 4.102, AUC: 0.888, AP: 0.881, Completeness: 0.377, Homogeneity: 0.357, NMI: 0.367
# Epoch: 078, Loss: 4.182, AUC: 0.889, AP: 0.882, Completeness: 0.397, Homogeneity: 0.406, NMI: 0.402
# Epoch: 079, Loss: 4.263, AUC: 0.890, AP: 0.884, Completeness: 0.424, Homogeneity: 0.416, NMI: 0.420
# Epoch: 080, Loss: 4.242, AUC: 0.891, AP: 0.885, Completeness: 0.355, Homogeneity: 0.364, NMI: 0.360
# Epoch: 081, Loss: 4.217, AUC: 0.892, AP: 0.886, Completeness: 0.364, Homogeneity: 0.371, NMI: 0.368
# Epoch: 082, Loss: 4.238, AUC: 0.894, AP: 0.888, Completeness: 0.423, Homogeneity: 0.432, NMI: 0.428
# Epoch: 083, Loss: 4.218, AUC: 0.895, AP: 0.889, Completeness: 0.432, Homogeneity: 0.440, NMI: 0.436
# Epoch: 084, Loss: 4.235, AUC: 0.897, AP: 0.891, Completeness: 0.397, Homogeneity: 0.394, NMI: 0.396
# Epoch: 085, Loss: 4.200, AUC: 0.898, AP: 0.892, Completeness: 0.434, Homogeneity: 0.441, NMI: 0.438
# Epoch: 086, Loss: 4.121, AUC: 0.900, AP: 0.893, Completeness: 0.428, Homogeneity: 0.440, NMI: 0.434
# Epoch: 087, Loss: 4.101, AUC: 0.901, AP: 0.895, Completeness: 0.421, Homogeneity: 0.430, NMI: 0.425
# Epoch: 088, Loss: 4.038, AUC: 0.903, AP: 0.896, Completeness: 0.449, Homogeneity: 0.457, NMI: 0.453
# Epoch: 089, Loss: 3.975, AUC: 0.904, AP: 0.897, Completeness: 0.442, Homogeneity: 0.457, NMI: 0.449
# Epoch: 090, Loss: 3.915, AUC: 0.904, AP: 0.897, Completeness: 0.493, Homogeneity: 0.480, NMI: 0.486
# Epoch: 091, Loss: 3.897, AUC: 0.905, AP: 0.898, Completeness: 0.452, Homogeneity: 0.465, NMI: 0.458
# Epoch: 092, Loss: 3.790, AUC: 0.906, AP: 0.899, Completeness: 0.478, Homogeneity: 0.474, NMI: 0.476
# Epoch: 093, Loss: 3.882, AUC: 0.907, AP: 0.900, Completeness: 0.458, Homogeneity: 0.472, NMI: 0.465
# Epoch: 094, Loss: 3.904, AUC: 0.908, AP: 0.901, Completeness: 0.462, Homogeneity: 0.475, NMI: 0.468
# Epoch: 095, Loss: 3.791, AUC: 0.909, AP: 0.902, Completeness: 0.455, Homogeneity: 0.475, NMI: 0.465
# Epoch: 096, Loss: 3.910, AUC: 0.910, AP: 0.903, Completeness: 0.453, Homogeneity: 0.474, NMI: 0.464
# Epoch: 097, Loss: 3.909, AUC: 0.911, AP: 0.904, Completeness: 0.459, Homogeneity: 0.476, NMI: 0.467
# Epoch: 098, Loss: 3.836, AUC: 0.912, AP: 0.905, Completeness: 0.476, Homogeneity: 0.480, NMI: 0.478
# Epoch: 099, Loss: 3.809, AUC: 0.912, AP: 0.905, Completeness: 0.440, Homogeneity: 0.440, NMI: 0.440
# Epoch: 100, Loss: 3.860, AUC: 0.913, AP: 0.905, Completeness: 0.458, Homogeneity: 0.475, NMI: 0.467
# Epoch: 101, Loss: 3.845, AUC: 0.913, AP: 0.905, Completeness: 0.458, Homogeneity: 0.476, NMI: 0.466
# Epoch: 102, Loss: 3.882, AUC: 0.912, AP: 0.905, Completeness: 0.463, Homogeneity: 0.471, NMI: 0.467
# Epoch: 103, Loss: 3.778, AUC: 0.912, AP: 0.905, Completeness: 0.458, Homogeneity: 0.476, NMI: 0.467
# Epoch: 104, Loss: 3.887, AUC: 0.912, AP: 0.905, Completeness: 0.465, Homogeneity: 0.474, NMI: 0.469
# Epoch: 105, Loss: 3.806, AUC: 0.912, AP: 0.905, Completeness: 0.454, Homogeneity: 0.477, NMI: 0.465
# Epoch: 106, Loss: 3.869, AUC: 0.912, AP: 0.906, Completeness: 0.464, Homogeneity: 0.472, NMI: 0.468
# Epoch: 107, Loss: 3.904, AUC: 0.913, AP: 0.907, Completeness: 0.464, Homogeneity: 0.472, NMI: 0.468
# Epoch: 108, Loss: 3.774, AUC: 0.913, AP: 0.908, Completeness: 0.464, Homogeneity: 0.472, NMI: 0.468
# Epoch: 109, Loss: 3.902, AUC: 0.914, AP: 0.909, Completeness: 0.466, Homogeneity: 0.474, NMI: 0.470
# Epoch: 110, Loss: 3.750, AUC: 0.914, AP: 0.909, Completeness: 0.449, Homogeneity: 0.470, NMI: 0.459
# Epoch: 111, Loss: 3.873, AUC: 0.914, AP: 0.910, Completeness: 0.445, Homogeneity: 0.468, NMI: 0.456
# Epoch: 112, Loss: 3.777, AUC: 0.915, AP: 0.911, Completeness: 0.463, Homogeneity: 0.472, NMI: 0.468
# Epoch: 113, Loss: 3.774, AUC: 0.915, AP: 0.911, Completeness: 0.435, Homogeneity: 0.442, NMI: 0.439
# Epoch: 114, Loss: 3.854, AUC: 0.916, AP: 0.912, Completeness: 0.466, Homogeneity: 0.475, NMI: 0.470
# Epoch: 115, Loss: 3.783, AUC: 0.916, AP: 0.912, Completeness: 0.456, Homogeneity: 0.463, NMI: 0.460
# Epoch: 116, Loss: 3.770, AUC: 0.917, AP: 0.913, Completeness: 0.457, Homogeneity: 0.464, NMI: 0.461
# Epoch: 117, Loss: 3.715, AUC: 0.917, AP: 0.913, Completeness: 0.457, Homogeneity: 0.466, NMI: 0.461
# Epoch: 118, Loss: 3.804, AUC: 0.918, AP: 0.914, Completeness: 0.456, Homogeneity: 0.464, NMI: 0.460
# Epoch: 119, Loss: 3.728, AUC: 0.919, AP: 0.915, Completeness: 0.457, Homogeneity: 0.466, NMI: 0.461
# Epoch: 120, Loss: 3.755, AUC: 0.920, AP: 0.915, Completeness: 0.466, Homogeneity: 0.476, NMI: 0.471
# Epoch: 121, Loss: 3.782, AUC: 0.920, AP: 0.916, Completeness: 0.466, Homogeneity: 0.476, NMI: 0.471
# Epoch: 122, Loss: 3.694, AUC: 0.921, AP: 0.916, Completeness: 0.458, Homogeneity: 0.458, NMI: 0.458
# Epoch: 123, Loss: 3.760, AUC: 0.921, AP: 0.916, Completeness: 0.464, Homogeneity: 0.481, NMI: 0.472
# Epoch: 124, Loss: 3.742, AUC: 0.921, AP: 0.916, Completeness: 0.455, Homogeneity: 0.463, NMI: 0.459
# Epoch: 125, Loss: 3.763, AUC: 0.921, AP: 0.916, Completeness: 0.444, Homogeneity: 0.425, NMI: 0.434
# Epoch: 126, Loss: 3.697, AUC: 0.921, AP: 0.916, Completeness: 0.456, Homogeneity: 0.465, NMI: 0.460
# Epoch: 127, Loss: 3.764, AUC: 0.921, AP: 0.916, Completeness: 0.456, Homogeneity: 0.440, NMI: 0.448
# Epoch: 128, Loss: 3.747, AUC: 0.921, AP: 0.916, Completeness: 0.475, Homogeneity: 0.484, NMI: 0.479
# Epoch: 129, Loss: 3.814, AUC: 0.921, AP: 0.915, Completeness: 0.474, Homogeneity: 0.482, NMI: 0.478
# Epoch: 130, Loss: 3.764, AUC: 0.922, AP: 0.915, Completeness: 0.466, Homogeneity: 0.474, NMI: 0.470
# Epoch: 131, Loss: 3.777, AUC: 0.922, AP: 0.916, Completeness: 0.478, Homogeneity: 0.486, NMI: 0.482
# Epoch: 132, Loss: 3.827, AUC: 0.922, AP: 0.916, Completeness: 0.465, Homogeneity: 0.478, NMI: 0.472
# Epoch: 133, Loss: 3.768, AUC: 0.923, AP: 0.917, Completeness: 0.478, Homogeneity: 0.486, NMI: 0.482
# Epoch: 134, Loss: 3.767, AUC: 0.924, AP: 0.917, Completeness: 0.466, Homogeneity: 0.474, NMI: 0.470
# Epoch: 135, Loss: 3.839, AUC: 0.924, AP: 0.918, Completeness: 0.459, Homogeneity: 0.442, NMI: 0.451
# Epoch: 136, Loss: 3.718, AUC: 0.925, AP: 0.919, Completeness: 0.458, Homogeneity: 0.441, NMI: 0.449
# Epoch: 137, Loss: 3.734, AUC: 0.925, AP: 0.919, Completeness: 0.475, Homogeneity: 0.483, NMI: 0.479
# Epoch: 138, Loss: 3.760, AUC: 0.925, AP: 0.919, Completeness: 0.465, Homogeneity: 0.435, NMI: 0.449
# Epoch: 139, Loss: 3.701, AUC: 0.925, AP: 0.919, Completeness: 0.430, Homogeneity: 0.406, NMI: 0.418
# Epoch: 140, Loss: 3.748, AUC: 0.925, AP: 0.919, Completeness: 0.427, Homogeneity: 0.403, NMI: 0.414
# Epoch: 141, Loss: 3.652, AUC: 0.925, AP: 0.919, Completeness: 0.449, Homogeneity: 0.437, NMI: 0.443
# Epoch: 142, Loss: 3.698, AUC: 0.925, AP: 0.919, Completeness: 0.450, Homogeneity: 0.469, NMI: 0.459
# Epoch: 143, Loss: 3.684, AUC: 0.925, AP: 0.919, Completeness: 0.451, Homogeneity: 0.471, NMI: 0.461
# Epoch: 144, Loss: 3.674, AUC: 0.925, AP: 0.918, Completeness: 0.465, Homogeneity: 0.438, NMI: 0.451
# Epoch: 145, Loss: 3.699, AUC: 0.925, AP: 0.918, Completeness: 0.451, Homogeneity: 0.469, NMI: 0.460
# Epoch: 146, Loss: 3.659, AUC: 0.925, AP: 0.918, Completeness: 0.470, Homogeneity: 0.444, NMI: 0.456
# Epoch: 147, Loss: 3.656, AUC: 0.925, AP: 0.918, Completeness: 0.445, Homogeneity: 0.457, NMI: 0.451
# Epoch: 148, Loss: 3.745, AUC: 0.925, AP: 0.918, Completeness: 0.423, Homogeneity: 0.427, NMI: 0.425
# Epoch: 149, Loss: 3.680, AUC: 0.925, AP: 0.919, Completeness: 0.426, Homogeneity: 0.438, NMI: 0.432
# Epoch: 150, Loss: 3.664, AUC: 0.925, AP: 0.919, Completeness: 0.429, Homogeneity: 0.427, NMI: 0.428
# Epoch: 151, Loss: 3.662, AUC: 0.925, AP: 0.919, Completeness: 0.432, Homogeneity: 0.418, NMI: 0.425
# Epoch: 152, Loss: 3.610, AUC: 0.925, AP: 0.919, Completeness: 0.422, Homogeneity: 0.427, NMI: 0.425
# Epoch: 153, Loss: 3.582, AUC: 0.925, AP: 0.920, Completeness: 0.435, Homogeneity: 0.446, NMI: 0.440
# Epoch: 154, Loss: 3.689, AUC: 0.925, AP: 0.920, Completeness: 0.438, Homogeneity: 0.429, NMI: 0.433
# Epoch: 155, Loss: 3.602, AUC: 0.925, AP: 0.919, Completeness: 0.484, Homogeneity: 0.478, NMI: 0.481
# Epoch: 156, Loss: 3.607, AUC: 0.925, AP: 0.919, Completeness: 0.428, Homogeneity: 0.448, NMI: 0.438
# Epoch: 157, Loss: 3.591, AUC: 0.925, AP: 0.920, Completeness: 0.434, Homogeneity: 0.433, NMI: 0.433
# Epoch: 158, Loss: 3.632, AUC: 0.925, AP: 0.920, Completeness: 0.406, Homogeneity: 0.426, NMI: 0.416
# Epoch: 159, Loss: 3.570, AUC: 0.925, AP: 0.920, Completeness: 0.402, Homogeneity: 0.399, NMI: 0.401
# Epoch: 160, Loss: 3.655, AUC: 0.925, AP: 0.920, Completeness: 0.425, Homogeneity: 0.443, NMI: 0.434
# Epoch: 161, Loss: 3.614, AUC: 0.925, AP: 0.920, Completeness: 0.402, Homogeneity: 0.423, NMI: 0.413
# Epoch: 162, Loss: 3.596, AUC: 0.925, AP: 0.920, Completeness: 0.430, Homogeneity: 0.445, NMI: 0.437
# Epoch: 163, Loss: 3.619, AUC: 0.925, AP: 0.920, Completeness: 0.413, Homogeneity: 0.410, NMI: 0.412
# Epoch: 164, Loss: 3.596, AUC: 0.925, AP: 0.920, Completeness: 0.426, Homogeneity: 0.448, NMI: 0.437
# Epoch: 165, Loss: 3.629, AUC: 0.924, AP: 0.920, Completeness: 0.405, Homogeneity: 0.385, NMI: 0.395
# Epoch: 166, Loss: 3.549, AUC: 0.924, AP: 0.922, Completeness: 0.405, Homogeneity: 0.416, NMI: 0.410
# Epoch: 167, Loss: 3.575, AUC: 0.924, AP: 0.922, Completeness: 0.419, Homogeneity: 0.426, NMI: 0.423
# Epoch: 168, Loss: 3.514, AUC: 0.924, AP: 0.922, Completeness: 0.426, Homogeneity: 0.422, NMI: 0.424
# Epoch: 169, Loss: 3.518, AUC: 0.925, AP: 0.922, Completeness: 0.423, Homogeneity: 0.439, NMI: 0.431
# Epoch: 170, Loss: 3.574, AUC: 0.925, AP: 0.922, Completeness: 0.406, Homogeneity: 0.412, NMI: 0.409
# Epoch: 171, Loss: 3.511, AUC: 0.925, AP: 0.922, Completeness: 0.417, Homogeneity: 0.409, NMI: 0.413
# Epoch: 172, Loss: 3.543, AUC: 0.925, AP: 0.922, Completeness: 0.454, Homogeneity: 0.456, NMI: 0.455
# Epoch: 173, Loss: 3.559, AUC: 0.925, AP: 0.922, Completeness: 0.429, Homogeneity: 0.451, NMI: 0.439
# Epoch: 174, Loss: 3.550, AUC: 0.925, AP: 0.923, Completeness: 0.422, Homogeneity: 0.418, NMI: 0.420
# Epoch: 175, Loss: 3.553, AUC: 0.925, AP: 0.923, Completeness: 0.419, Homogeneity: 0.411, NMI: 0.415
# Epoch: 176, Loss: 3.553, AUC: 0.925, AP: 0.923, Completeness: 0.412, Homogeneity: 0.407, NMI: 0.410
# Epoch: 177, Loss: 3.515, AUC: 0.925, AP: 0.923, Completeness: 0.463, Homogeneity: 0.471, NMI: 0.467
# Epoch: 178, Loss: 3.460, AUC: 0.926, AP: 0.923, Completeness: 0.430, Homogeneity: 0.448, NMI: 0.439
# Epoch: 179, Loss: 3.487, AUC: 0.926, AP: 0.924, Completeness: 0.418, Homogeneity: 0.433, NMI: 0.426
# Epoch: 180, Loss: 3.440, AUC: 0.927, AP: 0.924, Completeness: 0.464, Homogeneity: 0.470, NMI: 0.467
# Epoch: 181, Loss: 3.441, AUC: 0.927, AP: 0.924, Completeness: 0.448, Homogeneity: 0.447, NMI: 0.448
# Epoch: 182, Loss: 3.424, AUC: 0.927, AP: 0.924, Completeness: 0.394, Homogeneity: 0.406, NMI: 0.400
# Epoch: 183, Loss: 3.471, AUC: 0.927, AP: 0.923, Completeness: 0.459, Homogeneity: 0.462, NMI: 0.461
# Epoch: 184, Loss: 3.483, AUC: 0.927, AP: 0.923, Completeness: 0.440, Homogeneity: 0.454, NMI: 0.447
# Epoch: 185, Loss: 3.455, AUC: 0.926, AP: 0.923, Completeness: 0.455, Homogeneity: 0.464, NMI: 0.459
# Epoch: 186, Loss: 3.503, AUC: 0.926, AP: 0.923, Completeness: 0.455, Homogeneity: 0.464, NMI: 0.459
# Epoch: 187, Loss: 3.407, AUC: 0.926, AP: 0.922, Completeness: 0.472, Homogeneity: 0.476, NMI: 0.474
# Epoch: 188, Loss: 3.512, AUC: 0.925, AP: 0.922, Completeness: 0.439, Homogeneity: 0.454, NMI: 0.446
# Epoch: 189, Loss: 3.446, AUC: 0.925, AP: 0.922, Completeness: 0.420, Homogeneity: 0.419, NMI: 0.419
# Epoch: 190, Loss: 3.487, AUC: 0.925, AP: 0.922, Completeness: 0.377, Homogeneity: 0.392, NMI: 0.384
# Epoch: 191, Loss: 3.431, AUC: 0.925, AP: 0.923, Completeness: 0.417, Homogeneity: 0.435, NMI: 0.426
# Epoch: 192, Loss: 3.502, AUC: 0.925, AP: 0.923, Completeness: 0.458, Homogeneity: 0.475, NMI: 0.466
# Epoch: 193, Loss: 3.495, AUC: 0.925, AP: 0.923, Completeness: 0.441, Homogeneity: 0.464, NMI: 0.452
# Epoch: 194, Loss: 3.406, AUC: 0.925, AP: 0.923, Completeness: 0.486, Homogeneity: 0.483, NMI: 0.485
# Epoch: 195, Loss: 3.490, AUC: 0.924, AP: 0.922, Completeness: 0.436, Homogeneity: 0.459, NMI: 0.447
# Epoch: 196, Loss: 3.523, AUC: 0.924, AP: 0.922, Completeness: 0.415, Homogeneity: 0.423, NMI: 0.419
# Epoch: 197, Loss: 3.432, AUC: 0.923, AP: 0.922, Completeness: 0.425, Homogeneity: 0.442, NMI: 0.433
# Epoch: 198, Loss: 3.520, AUC: 0.922, AP: 0.921, Completeness: 0.456, Homogeneity: 0.464, NMI: 0.460
# Epoch: 199, Loss: 3.460, AUC: 0.922, AP: 0.921, Completeness: 0.427, Homogeneity: 0.428, NMI: 0.428
# Epoch: 200, Loss: 3.499, AUC: 0.922, AP: 0.920, Completeness: 0.411, Homogeneity: 0.425, NMI: 0.418

# %%
@torch.no_grad()
def plot_points(colors):
    model.eval()
    z = model.encode(data.x, data.train_pos_edge_index)
    z = TSNE(n_components=2).fit_transform(z.cpu().numpy())
    y = data.y.cpu().numpy()

    fig = plt.figure(1, figsize=(8, 8))
    fig.clf()
    for i in range(dataset.num_classes):
        plt.scatter(z[y == i, 0], z[y == i, 1], s=20, color=colors[i])
    plt.axis('off')
    plt.show()

# %%
#%%
colors = ['#ffc0cb', '#bada55', '#008080', '#420420', '#7fe5f0', '#065535', '#ffd700']
plot_points(colors)
