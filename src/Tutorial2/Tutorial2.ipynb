# %% [markdown]
# # Tutorial2: PyTorch basics

# %% [markdown]
# ## Outline

# %% [markdown]
# - Datasets
# - Models
# - Losses
# - Optimizers

# %% [markdown]
# Official resources:
# * [Deep Learning with PyTorch: a 60 Minute Blitz](https://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html)
# * [PyTorch documentation](https://pytorch.org/docs/stable/index.html)

# %% [markdown]
# Here no details, mostly visualization, with linear regression.

# %% [markdown]
# ### Imports

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from matplotlib import colors

plt.rcParams.update({'font.size': 16})

# %%
x = torch.rand(20, 5)
((x.norm(dim=1) - 1).abs() < 1e-10).float()
print(x)
# Out:
# tensor([[0.2481, 0.6856, 0.7432, 0.2125, 0.6088],
#         [0.3810, 0.7601, 0.6662, 0.2155, 0.5979],
#         [0.4657, 0.6786, 0.0416, 0.4017, 0.4862],
#         [0.5332, 0.9644, 0.4304, 0.9086, 0.3588],
#         [0.1824, 0.8794, 0.4900, 0.4604, 0.1599],
#         [0.9394, 0.2599, 0.9725, 0.8204, 0.3717],
#         [0.1064, 0.9384, 0.5241, 0.4186, 0.5918],
#         [0.1495, 0.0839, 0.0747, 0.1988, 0.0792],
#         [0.7361, 0.3702, 0.2892, 0.8159, 0.1198],
#         [0.7840, 0.1595, 0.8178, 0.5741, 0.9133],
#         [0.7744, 0.8909, 0.8259, 0.9228, 0.3967],
#         [0.9786, 0.3825, 0.5486, 0.0382, 0.2248],
#         [0.1752, 0.9700, 0.8893, 0.0619, 0.7345],
#         [0.8652, 0.8145, 0.3403, 0.6931, 0.4298],
#         [0.4102, 0.7293, 0.1870, 0.6519, 0.3067],
#         [0.0960, 0.7000, 0.9239, 0.2267, 0.7026],
#         [0.6219, 0.2848, 0.7036, 0.2631, 0.9580],
#         [0.9345, 0.0765, 0.5507, 0.6630, 0.4873],
#         [0.0090, 0.6146, 0.6973, 0.1625, 0.8300],
#         [0.9320, 0.3833, 0.6361, 0.5103, 0.1844]])

# %% [markdown]
# ## Datasets

# %% [markdown]
# ### A raw dataset

# %% [markdown]
# The data are obtained from the model
# $$
# x \mapsto y:=Ax + b
# $$
# with $x\in\mathbb R^{input\_dim}$ and $y\in\mathbb R^{output\_dim}$.

# %%
input_dim = 1
output_dim = 1

A = 2 * np.random.rand(output_dim, input_dim) - 1
b = 2 * np.random.rand(output_dim) - 1

true_model = lambda x: A @ x + b

# %% [markdown]
# We get a training set by randomly sampling and noisy observations
# \begin{align*}
# &x_i \sim U([-1, 1])\\
# &y_i = A x_i + b + \nu_i
# \end{align*}

# %%
n_train = 1000
noise_level = 0.04

# Generate a random set of n_train samples
X_train = np.random.rand(n_train, input_dim)
y_train = np.array([true_model(x) for x in X_train])

# Add some noise
y_train += noise_level * np.random.standard_normal(size=y_train.shape)

# %%
if input_dim == output_dim == 1:
    fig = plt.figure()
    fig.clf()
    ax = fig.gca()
    ax.plot(X_train, y_train, '.')
    ax.grid(True)
    ax.set_xlabel('X_train')
    ax.set_ylabel('y_train')

# %% [markdown]
# ### PyTorch `Dataset`

# %%
#%% Dataset to manage vector to vector data
class VectorialDataset(torch.utils.data.Dataset):
    def __init__(self, input_data, output_data):
        super(VectorialDataset, self).__init__()
        self.input_data = torch.tensor(input_data.astype('f'))
        self.output_data = torch.tensor(output_data.astype('f'))

    def __len__(self):
        return self.input_data.shape[0]

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()
        sample = (self.input_data[idx, :], self.output_data[idx, :])
        return sample

# %%
training_set = VectorialDataset(input_data=X_train, output_data=y_train)

# %%
len(training_set)
# Out:
# 1000

# %%
training_set[10:12]
# Out:
# (tensor([[0.9123],
#          [0.6719]]),
#  tensor([[0.0524],
#          [0.2235]]))

# %% [markdown]
# Here almost useless, but think about e.g. images.

# %% [markdown]
# ### PyTorch `DataLoader`

# %%
batch_size = 120
train_loader = torch.utils.data.DataLoader(
    training_set, batch_size=batch_size, shuffle=True
)

# %% [markdown]
# The role of `batch_size`:

# %%
for idx, batch in enumerate(train_loader):
    print(
        'Batch n. %2d: input size=%s, output size=%s'
        % (idx + 1, batch[0].shape, batch[1].shape)
    )
# Out:
# Batch n.  1: input size=torch.Size([120, 1]), output size=torch.Size([120, 1])
# Batch n.  2: input size=torch.Size([120, 1]), output size=torch.Size([120, 1])
# Batch n.  3: input size=torch.Size([120, 1]), output size=torch.Size([120, 1])
# Batch n.  4: input size=torch.Size([120, 1]), output size=torch.Size([120, 1])
# Batch n.  5: input size=torch.Size([120, 1]), output size=torch.Size([120, 1])
# Batch n.  6: input size=torch.Size([120, 1]), output size=torch.Size([120, 1])
# Batch n.  7: input size=torch.Size([120, 1]), output size=torch.Size([120, 1])
# Batch n.  8: input size=torch.Size([120, 1]), output size=torch.Size([120, 1])
# Batch n.  9: input size=torch.Size([40, 1]), output size=torch.Size([40, 1])

# %%
8 * 120
# Out:
# 960

# %% [markdown]
# The role of `shuffle`:

# %%
first_batch = []

for epoch in range(2):
    for idx, batch in enumerate(train_loader):
        if idx == 0:
            first_batch.append(batch)

np.c_[X_train[:batch_size], first_batch[0][0].numpy(), first_batch[1][0].numpy()]
# Out:
# array([[0.80257608, 0.91860962, 0.08245701],
#        [0.56157022, 0.58326864, 0.9634316 ],
#        [0.59850362, 0.06799199, 0.28711957],
#        [0.88294996, 0.47509429, 0.52444625],
#        [0.24755612, 0.03981995, 0.44399002],
#        [0.8974608 , 0.22476628, 0.68023044],
#        [0.2552202 , 0.98174953, 0.17011556],
#        [0.3214211 , 0.44733089, 0.0379445 ],
#        [0.66938232, 0.93295491, 0.04639535],
#        [0.51173296, 0.14966477, 0.72049302],
#        [0.91228614, 0.82307559, 0.96471596],
#        [0.6718533 , 0.5393706 , 0.73267269],
#        [0.45244023, 0.32680088, 0.83122993],
#        [0.44941468, 0.43039238, 0.32119069],
#        [0.52366571, 0.45957118, 0.40620497],
#        [0.30981289, 0.86412656, 0.38471586],
#        [0.58848085, 0.49199322, 0.62752116],
#        [0.40776115, 0.13300675, 0.74638397],
#        [0.30689196, 0.91599315, 0.72786224],
#        [0.37453388, 0.56286812, 0.83383042],
#        [0.20377608, 0.68244302, 0.96973348],
#        [0.7062034 , 0.50105631, 0.96167028],
#        [0.43799051, 0.76081139, 0.57887924],
#        [0.17423879, 0.16355585, 0.51664734],
#        [0.29133068, 0.63138926, 0.52167416],
#        [0.61947391, 0.65078384, 0.32185858],
#        [0.01642386, 0.19163299, 0.79939133],
#        [0.02348278, 0.75591832, 0.68941599],
#        [0.77949972, 0.68154937, 0.48558289],
#        [0.45262125, 0.4072265 , 0.42070061],
#        [0.91331936, 0.55419689, 0.04483451],
#        [0.44587648, 0.64784873, 0.23453666],
#        [0.17118739, 0.98902142, 0.90348274],
#        [0.74417184, 0.50248736, 0.87991971],
#        [0.95378649, 0.26619175, 0.33354047],
#        [0.15012029, 0.55950522, 0.92683333],
#        [0.69647742, 0.40969551, 0.73793101],
#        [0.42217999, 0.38505721, 0.46427125],
#        [0.42472225, 0.94135213, 0.16076064],
#        [0.38750783, 0.78237975, 0.46740091],
#        [0.65183694, 0.79217213, 0.57207042],
#        [0.86197321, 0.8203811 , 0.40076429],
#        [0.0264262 , 0.2513949 , 0.96476704],
#        [0.031879  , 0.25512025, 0.12857249],
#        [0.36309226, 0.93123364, 0.03849541],
#        [0.22539513, 0.60331118, 0.89556372],
#        [0.26365971, 0.39958325, 0.28219983],
#        [0.59925631, 0.95956767, 0.97250032],
#        [0.47509427, 0.78045344, 0.73793119],
#        [0.06149483, 0.48959374, 0.70447153],
#        [0.29180724, 0.08603236, 0.88491005],
#        [0.44554457, 0.04553498, 0.02094592],
#        [0.98322115, 0.33894312, 0.16912012],
#        [0.27513205, 0.77510577, 0.76196426],
#        [0.98686054, 0.23492245, 0.05405329],
#        [0.93240221, 0.47782341, 0.85818595],
#        [0.38505722, 0.79436189, 0.96981502],
#        [0.86412653, 0.2038857 , 0.25350326],
#        [0.57147555, 0.71811312, 0.41155046],
#        [0.3063375 , 0.85421431, 0.36532587],
#        [0.33210513, 0.52676678, 0.56245339],
#        [0.45346667, 0.29180723, 0.17118739],
#        [0.04483451, 0.76814699, 0.45779166],
#        [0.27200436, 0.10936709, 0.84159362],
#        [0.54234642, 0.5160467 , 0.89385092],
#        [0.81370831, 0.07707642, 0.75351149],
#        [0.14871491, 0.85333991, 0.39093086],
#        [0.58022089, 0.46080288, 0.4543227 ],
#        [0.51604668, 0.20088771, 0.66213459],
#        [0.37793439, 0.41521305, 0.67083097],
#        [0.71058458, 0.06315796, 0.60555333],
#        [0.44733089, 0.031879  , 0.2913641 ],
#        [0.93123362, 0.79335415, 0.46129066],
#        [0.63149338, 0.9041062 , 0.46441191],
#        [0.37840508, 0.3276937 , 0.2671569 ],
#        [0.10936709, 0.64731395, 0.62795186],
#        [0.72039201, 0.22588792, 0.8203811 ],
#        [0.0379445 , 0.71058458, 0.45346668],
#        [0.49508136, 0.45557809, 0.35248888],
#        [0.01033509, 0.38750783, 0.13035731],
#        [0.84908443, 0.12857249, 0.86224741],
#        [0.46080287, 0.49997205, 0.39394531],
#        [0.81205728, 0.60203069, 0.10964566],
#        [0.14824435, 0.77618301, 0.5518257 ],
#        [0.57875018, 0.04817801, 0.47170314],
#        [0.59565871, 0.95626771, 0.87757581],
#        [0.81506578, 0.70590067, 0.30633751],
#        [0.52330022, 0.28949818, 0.2695173 ],
#        [0.81245741, 0.89385092, 0.63285542],
#        [0.85818596, 0.547701  , 0.82170939],
#        [0.67707844, 0.16617711, 0.44532272],
#        [0.2449103 , 0.25612521, 0.82740468],
#        [0.28473049, 0.7802074 , 0.73828578],
#        [0.87991969, 0.58048123, 0.22476628],
#        [0.61362085, 0.90348274, 0.65387684],
#        [0.76081141, 0.17423879, 0.03764905],
#        [0.64421247, 0.14254804, 0.85727012],
#        [0.46740091, 0.76894653, 0.0803305 ],
#        [0.79248395, 0.14626381, 0.31532252],
#        [0.92178508, 0.79286379, 0.37204057],
#        [0.19163298, 0.61317748, 0.57901436],
#        [0.41155045, 0.80490124, 0.87612814],
#        [0.27470412, 0.03054667, 0.80211186],
#        [0.48558288, 0.26509199, 0.17497149],
#        [0.78536932, 0.03610171, 0.5914433 ],
#        [0.23943916, 0.57242155, 0.44554457],
#        [0.18623827, 0.60935879, 0.41296977],
#        [0.97218058, 0.40750772, 0.66504264],
#        [0.64784872, 0.67619121, 0.6024918 ],
#        [0.09202877, 0.21644944, 0.18086314],
#        [0.95289146, 0.61035049, 0.00342802],
#        [0.21290474, 0.32325745, 0.09142272],
#        [0.03383353, 0.2524116 , 0.56773013],
#        [0.88193433, 0.21936212, 0.98183137],
#        [0.51850289, 0.48830175, 0.79286379],
#        [0.05769836, 0.82643485, 0.12303519],
#        [0.76102681, 0.27513206, 0.92806214],
#        [0.98183135, 0.78854871, 0.72249383],
#        [0.69189319, 0.23438728, 0.37717584],
#        [0.95067503, 0.56979465, 0.82008249]])

# %% [markdown]
# ## Models

# %% [markdown]
# We implement a linear model $$x \mapsto model(x):=A x + b$$
#
# with $A\in \mathbb{R}^{input\_dim\times output\_dim}$, $b\in\mathbb{R}^{output\_dim}$.

# %%
import torch.nn as nn
import torch

#%% Linear layer
class LinearModel(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(LinearModel, self).__init__()

        self.input_dim = input_dim
        self.output_dim = output_dim

        self.linear = nn.Linear(self.input_dim, self.output_dim, bias=True)

    def forward(self, x):
        out = self.linear(x)
        return out

    def reset(self):
        self.linear.reset_parameters()

# %%
model = LinearModel(input_dim, output_dim)

# %% [markdown]
# ### Model inspection

# %%
print(model)
# Out:
# LinearModel(
#   (linear): Linear(in_features=1, out_features=1, bias=True)
# )

# %% [markdown]
# See [pytorch.org/docs/stable/nn.html](https://pytorch.org/docs/stable/nn.html) for many other layers.

# %%
list(model.parameters())
# Out:
# [Parameter containing:
#  tensor([[-0.5808]], requires_grad=True),
#  Parameter containing:
#  tensor([0.7334], requires_grad=True)]

# %%
model.linear.weight
# Out:
# Parameter containing:
# tensor([[-0.5808]], requires_grad=True)

# %%
model.linear.bias
# Out:
# Parameter containing:
# tensor([0.7334], requires_grad=True)

# %% [markdown]
# ### The `forward` method

# %%
x = torch.randn(5, input_dim)
model.forward(x)
# Out:
# tensor([[1.1787],
#         [0.3771],
#         [0.5346],
#         [0.2999],
#         [0.5576]], grad_fn=<AddmmBackward0>)

# %%
[model.linear.weight @ xx + model.linear.bias for xx in x]
# Out:
# [tensor([1.1787], grad_fn=<AddBackward0>),
#  tensor([0.3771], grad_fn=<AddBackward0>),
#  tensor([0.5346], grad_fn=<AddBackward0>),
#  tensor([0.2999], grad_fn=<AddBackward0>),
#  tensor([0.5576], grad_fn=<AddBackward0>)]

# %%
if input_dim == output_dim == 1:
    fig = plt.figure()
    fig.clf()
    ax = fig.gca()
    ax.plot(training_set.input_data, training_set.output_data, '.')
    ax.plot(
        training_set.input_data,
        model.forward(training_set.input_data).detach().numpy(),
        '.',
    )
    ax.grid(True)
    ax.set_xlabel('X_train')
    ax.legend(['y_train', 'model(X_train)'])

# %% [markdown]
# ## Losses

# %% [markdown]
# ### The MSE loss

# %% [markdown]
# The MSE loss is
# $$
# L(y, y') = \|y-y'\|_2^2
# $$

# %%
import torch.nn as nn

loss_fun = nn.MSELoss(reduction='mean')

# %% [markdown]
# More at [pytorch.org/docs/stable/nn.html#loss-functions](https://pytorch.org/docs/stable/nn.html#loss-functions)

# %%
x = torch.tensor(np.array([1, 2, 1]).astype('f'))
z = torch.tensor(np.array([0, 0, 0]).astype('f'))
loss_fun(x, z)
# Out:
# tensor(2.)

# %% [markdown]
# ### Giving a score to the model (parameters) given the training set

# %% [markdown]
# The loss for one data pair $(x_i, y_i)$ is
# $$
# L(model(x_i), y_i)
# $$
#
# The cumulative (average) loss on the training set is
# $$
# L(X_{train}, y_{train}):=\frac{1}{n_{train}} \sum_{i=1}^{n_{train}} L(model(x_i), y_i)
# $$

# %%
if input_dim == output_dim == 1:

    state_dict = model.state_dict()

    ww, bb = np.meshgrid(np.linspace(-2, 2, 30), np.linspace(-2, 2, 30))

    loss_values = 0 * ww
    for i in range(ww.shape[0]):
        for j in range(ww.shape[1]):
            state_dict['linear.weight'] = torch.tensor([[ww[i, j]]])
            state_dict['linear.bias'] = torch.tensor([bb[i, j]])
            model.load_state_dict(state_dict)
            loss_values[i, j] = loss_fun(
                model.forward(training_set.input_data), training_set.output_data
            )

    fig = plt.figure(figsize=(10, 8))
    fig.clf()
    ax = fig.gca()
    levels = np.logspace(np.log(np.min(loss_values)), np.log(np.max(loss_values)), 20)
    c = ax.contourf(ww, bb, loss_values, levels=levels, norm=colors.LogNorm())
    plt.colorbar(c)
    ax.plot(A[0], b, 'r*', markersize=10)
    ax.set_ylabel('bias')
    ax.set_xlabel('weight')
    ax.legend(['(A, b)'])

    ax.grid(True)

# %% [markdown]
# ## Optimization

# %% [markdown]
# Goal: minimize the loss given the data:
# $$
# \min\limits_{par \in model} L(X_{train}, y_{train})
# =\min\limits_{par \in model} \frac{1}{n_{train}} \sum_{i=1}^{n_{train}} L(x_i, model(x_i))
# $$
#
# In this case $par =\{A, b\}$.

# %% [markdown]
# Iterative gradient based optimization:
# \begin{align*}
# par^{(0)} &= par_0\\
# par^{(k+1)} &=  par^{(k)} - \eta^{(k)} \nabla_{par} L(X_{train}, y_{train})
# \end{align*}
# with learning rate $\eta^{(k)}$.

# %% [markdown]
# ### Gradients

# %% [markdown]
# The model is
# $$
# model(x) = A x + b
# $$
#
# With $input\_dim = output\_dim = 1$ we have $A:=a\in\mathbb{R},\ b\in\mathbb{R}$.
#
# For a data pair $(x, y)$ the loss is
# \begin{align*}
# L(x, y)
# &= \|model(x)-y\|_2^2\\
# &= (model(x)-y)^2\\
# &= (a x + b - y)^2\\
# &= a^2 x^2 + 2 a b x - 2 a xy + b^2 -2 b y + y^2.
# \end{align*}
#
# We can compute
# \begin{align*}
# \nabla_a L(x, y)
# &= 2 a x^2 + 2 b x - 2 xy
# =2 x (a x + b - y)\\
# \nabla_b L(x, y)
# &= 2 a x + 2 b - 2 y
# = 2 (ax + b - y).
# \end{align*}

# %%
x = torch.randn(1, input_dim)
y = torch.randn(1, output_dim)

model.zero_grad()
loss = loss_fun(model.forward(x), y)
loss.backward()

# %%
if input_dim == output_dim == 1:
    print(model.linear.weight.grad)
    print(2 * x * (model.linear.weight * x + model.linear.bias - y))

    print(model.linear.bias.grad)
    print(2 * (model.linear.weight * x + model.linear.bias - y))
# Out:
# tensor([[1.9040]])
# tensor([[1.9040]], grad_fn=<MulBackward0>)
# tensor([3.8656])
# tensor([[3.8656]], grad_fn=<MulBackward0>)

# %% [markdown]
# ### Handmade optimization

# %%
if input_dim == output_dim == 1:

    num_iter = 200
    lr = 0.5   # 0.01

    train_hist = {}
    train_hist['weight'] = []
    train_hist['bias'] = []

    model.reset()
    state_dict = model.state_dict()

    for _ in range(num_iter):

        model.zero_grad()
        loss = loss_fun(
            model.forward(training_set.input_data), training_set.output_data
        )
        loss.backward()

        w = model.linear.weight.item()
        b = model.linear.bias.item()

        dw = model.linear.weight.grad.item()
        db = model.linear.bias.grad.item()

        state_dict['linear.weight'] += torch.tensor([-lr * dw])
        state_dict['linear.bias'] += torch.tensor([-lr * db])
        model.load_state_dict(state_dict)

        train_hist['weight'].append(w)
        train_hist['bias'].append(b)

    for label in train_hist:
        train_hist[label] = np.array(train_hist[label])

# %%
if input_dim == output_dim == 1:
    fig = plt.figure(figsize=(8, 8))
    fig.clf()
    ax = fig.gca()
    levels = np.logspace(np.log(np.min(loss_values)), np.log(np.max(loss_values)), 20)
    ax.contourf(ww, bb, loss_values, levels=levels, norm=colors.LogNorm())
    ax.set_xlabel('weight')
    ax.set_ylabel('bias')
    ax.grid(True)
    ax.set_xlim(-2, 2)
    ax.set_ylim(-2, 2)

    ax.plot(train_hist['weight'], train_hist['bias'], '.-b')
    ax.plot(A[0], b, 'r*', markersize=10)

    # ax.legend(['optim', '(A, b)'])

# %% [markdown]
# ### Stochastic GD

# %% [markdown]
# * Avoid loading the full training set
# * Avoid evaluating the model on the full training set

# %% [markdown]
# At every step, compute the loss on a batch of data $(X^{(k)}, y^{(k)})\sim (X_{train}, y_{train})$:
#
# \begin{align*}
# L(X^{(k)}, y^{(k)}) := \sum_{(x, y) \in (X^{(k)}, y^{(k)})} L(x, model(x)).
# \end{align*}
#
# and then update with this approximated gradient:
# \begin{align*}
# par^{(k+1)} &=  par^{(k)} - \eta^{(k)} \nabla_{par} L(X^{(k)}, y^{(k)}).
# \end{align*}

# %% [markdown]
# ### PyTorch `optim`

# %%
lr = 0.1
weight_decay = 5e-4
optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

# %% [markdown]
# More at [pytorch.org/docs/stable/optim.html](https://pytorch.org/docs/stable/optim.html).

# %%
n_epochs = 100

# %%
train_hist = {}
train_hist['loss'] = []

if input_dim == output_dim == 1:
    train_hist['weight'] = []
    train_hist['bias'] = []

# Initialize training
model.reset()
model.train()

for epoch in range(n_epochs):
    for idx, batch in enumerate(train_loader):
        optimizer.zero_grad()
        loss = loss_fun(model.forward(batch[0]), batch[1])
        loss.backward()
        optimizer.step()

        train_hist['loss'].append(loss.item())
        if input_dim == output_dim == 1:
            train_hist['weight'].append(model.linear.weight.item())
            train_hist['bias'].append(model.linear.bias.item())

        print(
            '[Epoch %4d/%4d] [Batch %4d/%4d] Loss: % 2.2e'
            % (epoch + 1, n_epochs, idx + 1, len(train_loader), loss.item())
        )

model.eval()
# Out:
# [Epoch    1/ 100] [Batch    1/   9] Loss:  3.43e-01
# [Epoch    1/ 100] [Batch    2/   9] Loss:  1.68e-01
# [Epoch    1/ 100] [Batch    3/   9] Loss:  1.09e-01
# [Epoch    1/ 100] [Batch    4/   9] Loss:  4.83e-02
# [Epoch    1/ 100] [Batch    5/   9] Loss:  3.94e-02
# [Epoch    1/ 100] [Batch    6/   9] Loss:  6.11e-02
# [Epoch    1/ 100] [Batch    7/   9] Loss:  8.60e-02
# [Epoch    1/ 100] [Batch    8/   9] Loss:  1.03e-01
# [Epoch    1/ 100] [Batch    9/   9] Loss:  9.65e-02
# [Epoch    2/ 100] [Batch    1/   9] Loss:  8.38e-02
# [Epoch    2/ 100] [Batch    2/   9] Loss:  7.40e-02
# [Epoch    2/ 100] [Batch    3/   9] Loss:  4.56e-02
# [Epoch    2/ 100] [Batch    4/   9] Loss:  3.52e-02
# [Epoch    2/ 100] [Batch    5/   9] Loss:  2.16e-02
# [Epoch    2/ 100] [Batch    6/   9] Loss:  1.48e-02
# [Epoch    2/ 100] [Batch    7/   9] Loss:  1.96e-02
# [Epoch    2/ 100] [Batch    8/   9] Loss:  2.27e-02
# [Epoch    2/ 100] [Batch    9/   9] Loss:  3.24e-02
# [Epoch    3/ 100] [Batch    1/   9] Loss:  2.97e-02
# [Epoch    3/ 100] [Batch    2/   9] Loss:  2.84e-02
# [Epoch    3/ 100] [Batch    3/   9] Loss:  2.34e-02
# [Epoch    3/ 100] [Batch    4/   9] Loss:  1.54e-02
# [Epoch    3/ 100] [Batch    5/   9] Loss:  1.52e-02
# [Epoch    3/ 100] [Batch    6/   9] Loss:  1.05e-02
# [Epoch    3/ 100] [Batch    7/   9] Loss:  5.99e-03
# [Epoch    3/ 100] [Batch    8/   9] Loss:  5.25e-03
# [Epoch    3/ 100] [Batch    9/   9] Loss:  7.47e-03
# [Epoch    4/ 100] [Batch    1/   9] Loss:  6.74e-03
# [Epoch    4/ 100] [Batch    2/   9] Loss:  8.51e-03
# [Epoch    4/ 100] [Batch    3/   9] Loss:  8.39e-03
# [Epoch    4/ 100] [Batch    4/   9] Loss:  7.44e-03
# [Epoch    4/ 100] [Batch    5/   9] Loss:  6.64e-03
# [Epoch    4/ 100] [Batch    6/   9] Loss:  4.91e-03
# [Epoch    4/ 100] [Batch    7/   9] Loss:  2.87e-03
# [Epoch    4/ 100] [Batch    8/   9] Loss:  2.04e-03
# [Epoch    4/ 100] [Batch    9/   9] Loss:  1.74e-03
# [Epoch    5/ 100] [Batch    1/   9] Loss:  2.50e-03
# [Epoch    5/ 100] [Batch    2/   9] Loss:  2.60e-03
# [Epoch    5/ 100] [Batch    3/   9] Loss:  3.53e-03
# [Epoch    5/ 100] [Batch    4/   9] Loss:  3.21e-03
# [Epoch    5/ 100] [Batch    5/   9] Loss:  3.24e-03
# [Epoch    5/ 100] [Batch    6/   9] Loss:  3.47e-03
# [Epoch    5/ 100] [Batch    7/   9] Loss:  2.71e-03
# [Epoch    5/ 100] [Batch    8/   9] Loss:  1.46e-03
# [Epoch    5/ 100] [Batch    9/   9] Loss:  2.26e-03
# [Epoch    6/ 100] [Batch    1/   9] Loss:  1.61e-03
# [Epoch    6/ 100] [Batch    2/   9] Loss:  1.66e-03
# [Epoch    6/ 100] [Batch    3/   9] Loss:  2.35e-03
# [Epoch    6/ 100] [Batch    4/   9] Loss:  2.00e-03
# [Epoch    6/ 100] [Batch    5/   9] Loss:  2.71e-03
# [Epoch    6/ 100] [Batch    6/   9] Loss:  2.68e-03
# [Epoch    6/ 100] [Batch    7/   9] Loss:  2.41e-03
# [Epoch    6/ 100] [Batch    8/   9] Loss:  2.55e-03
# [Epoch    6/ 100] [Batch    9/   9] Loss:  1.65e-03
# [Epoch    7/ 100] [Batch    1/   9] Loss:  1.84e-03
# [Epoch    7/ 100] [Batch    2/   9] Loss:  1.80e-03
# [Epoch    7/ 100] [Batch    3/   9] Loss:  2.46e-03
# [Epoch    7/ 100] [Batch    4/   9] Loss:  2.26e-03
# [Epoch    7/ 100] [Batch    5/   9] Loss:  1.62e-03
# [Epoch    7/ 100] [Batch    6/   9] Loss:  1.85e-03
# [Epoch    7/ 100] [Batch    7/   9] Loss:  2.19e-03
# [Epoch    7/ 100] [Batch    8/   9] Loss:  2.03e-03
# [Epoch    7/ 100] [Batch    9/   9] Loss:  1.73e-03
# [Epoch    8/ 100] [Batch    1/   9] Loss:  1.78e-03
# [Epoch    8/ 100] [Batch    2/   9] Loss:  1.72e-03
# [Epoch    8/ 100] [Batch    3/   9] Loss:  1.50e-03
# [Epoch    8/ 100] [Batch    4/   9] Loss:  2.04e-03
# [Epoch    8/ 100] [Batch    5/   9] Loss:  1.96e-03
# [Epoch    8/ 100] [Batch    6/   9] Loss:  1.60e-03
# [Epoch    8/ 100] [Batch    7/   9] Loss:  1.53e-03
# [Epoch    8/ 100] [Batch    8/   9] Loss:  1.84e-03
# [Epoch    8/ 100] [Batch    9/   9] Loss:  2.11e-03
# [Epoch    9/ 100] [Batch    1/   9] Loss:  1.42e-03
# [Epoch    9/ 100] [Batch    2/   9] Loss:  1.49e-03
# [Epoch    9/ 100] [Batch    3/   9] Loss:  1.84e-03
# [Epoch    9/ 100] [Batch    4/   9] Loss:  1.60e-03
# [Epoch    9/ 100] [Batch    5/   9] Loss:  1.77e-03
# [Epoch    9/ 100] [Batch    6/   9] Loss:  1.49e-03
# [Epoch    9/ 100] [Batch    7/   9] Loss:  1.63e-03
# [Epoch    9/ 100] [Batch    8/   9] Loss:  1.56e-03
# [Epoch    9/ 100] [Batch    9/   9] Loss:  1.84e-03
# [Epoch   10/ 100] [Batch    1/   9] Loss:  1.66e-03
# [Epoch   10/ 100] [Batch    2/   9] Loss:  1.55e-03
# [Epoch   10/ 100] [Batch    3/   9] Loss:  1.66e-03
# [Epoch   10/ 100] [Batch    4/   9] Loss:  1.86e-03
# [Epoch   10/ 100] [Batch    5/   9] Loss:  1.76e-03
# [Epoch   10/ 100] [Batch    6/   9] Loss:  1.30e-03
# [Epoch   10/ 100] [Batch    7/   9] Loss:  1.64e-03
# [Epoch
 100] [Batch    2/   9] Loss:  1.43e-03
# [Epoch   91/ 100] [Batch    3/   9] Loss:  1.61e-03
# [Epoch   91/ 100] [Batch    4/   9] Loss:  1.55e-03
# [Epoch   91/ 100] [Batch    5/   9] Loss:  1.78e-03
# [Epoch   91/ 100] [Batch    6/   9] Loss:  1.52e-03
# [Epoch   91/ 100] [Batch    7/   9] Loss:  1.60e-03
# [Epoch   91/ 100] [Batch    8/   9] Loss:  1.69e-03
# [Epoch   91/ 100] [Batch    9/   9] Loss:  1.02e-03
# [Epoch   92/ 100] [Batch    1/   9] Loss:  1.52e-03
# [Epoch   92/ 100] [Batch    2/   9] Loss:  1.50e-03
# [Epoch   92/ 100] [Batch    3/   9] Loss:  1.46e-03
# [Epoch   92/ 100] [Batch    4/   9] Loss:  1.69e-03
# [Epoch   92/ 100] [Batch    5/   9] Loss:  1.54e-03
# [Epoch   92/ 100] [Batch    6/   9] Loss:  1.89e-03
# [Epoch   92/ 100] [Batch    7/   9] Loss:  1.62e-03
# [Epoch   92/ 100] [Batch    8/   9] Loss:  1.72e-03
# [Epoch   92/ 100] [Batch    9/   9] Loss:  1.17e-03
# [Epoch   93/ 100] [Batch    1/   9] Loss:  1.40e-03
# [Epoch   93/ 100] [Batch    2/   9] Loss:  1.65e-03
# [Epoch   93/ 100] [Batch    3/   9] Loss:  1.57e-03
# [Epoch   93/ 100] [Batch    4/   9] Loss:  1.58e-03
# [Epoch   93/ 100] [Batch    5/   9] Loss:  1.90e-03
# [Epoch   93/ 100] [Batch    6/   9] Loss:  1.32e-03
# [Epoch   93/ 100] [Batch    7/   9] Loss:  1.47e-03
# [Epoch   93/ 100] [Batch    8/   9] Loss:  1.82e-03
# [Epoch   93/ 100] [Batch    9/   9] Loss:  1.98e-03
# [Epoch   94/ 100] [Batch    1/   9] Loss:  1.66e-03
# [Epoch   94/ 100] [Batch    2/   9] Loss:  1.69e-03
# [Epoch   94/ 100] [Batch    3/   9] Loss:  1.48e-03
# [Epoch   94/ 100] [Batch    4/   9] Loss:  1.50e-03
# [Epoch   94/ 100] [Batch    5/   9] Loss:  1.62e-03
# [Epoch   94/ 100] [Batch    6/   9] Loss:  1.75e-03
# [Epoch   94/ 100] [Batch    7/   9] Loss:  1.91e-03
# [Epoch   94/ 100] [Batch    8/   9] Loss:  1.53e-03
# [Epoch   94/ 100] [Batch    9/   9] Loss:  1.02e-03
# [Epoch   95/ 100] [Batch    1/   9] Loss:  1.67e-03
# [Epoch   95/ 100] [Batch    2/   9] Loss:  1.70e-03
# [Epoch   95/ 100] [Batch    3/   9] Loss:  1.62e-03
# [Epoch   95/ 100] [Batch    4/   9] Loss:  1.40e-03
# [Epoch   95/ 100] [Batch    5/   9] Loss:  1.47e-03
# [Epoch   95/ 100] [Batch    6/   9] Loss:  1.64e-03
# [Epoch   95/ 100] [Batch    7/   9] Loss:  1.69e-03
# [Epoch   95/ 100] [Batch    8/   9] Loss:  1.69e-03
# [Epoch   95/ 100] [Batch    9/   9] Loss:  1.39e-03
# [Epoch   96/ 100] [Batch    1/   9] Loss:  1.62e-03
# [Epoch   96/ 100] [Batch    2/   9] Loss:  1.49e-03
# [Epoch   96/ 100] [Batch    3/   9] Loss:  1.55e-03
# [Epoch   96/ 100] [Batch    4/   9] Loss:  1.62e-03
# [Epoch   96/ 100] [Batch    5/   9] Loss:  1.65e-03
# [Epoch   96/ 100] [Batch    6/   9] Loss:  1.61e-03
# [Epoch   96/ 100] [Batch    7/   9] Loss:  1.83e-03
# [Epoch   96/ 100] [Batch    8/   9] Loss:  1.59e-03
# [Epoch   96/ 100] [Batch    9/   9] Loss:  1.01e-03
# [Epoch   97/ 100] [Batch    1/   9] Loss:  1.98e-03
# [Epoch   97/ 100] [Batch    2/   9] Loss:  1.65e-03
# [Epoch   97/ 100] [Batch    3/   9] Loss:  1.39e-03
# [Epoch   97/ 100] [Batch    4/   9] Loss:  1.28e-03
# [Epoch   97/ 100] [Batch    5/   9] Loss:  1.71e-03
# [Epoch   97/ 100] [Batch    6/   9] Loss:  1.61e-03
# [Epoch   97/ 100] [Batch    7/   9] Loss:  1.64e-03
# [Epoch   97/ 100] [Batch    8/   9] Loss:  1.45e-03
# [Epoch   97/ 100] [Batch    9/   9] Loss:  2.01e-03
# [Epoch   98/ 100] [Batch    1/   9] Loss:  1.75e-03
# [Epoch   98/ 100] [Batch    2/   9] Loss:  1.60e-03
# [Epoch   98/ 100] [Batch    3/   9] Loss:  1.45e-03
# [Epoch   98/ 100] [Batch    4/   9] Loss:  1.62e-03
# [Epoch   98/ 100] [Batch    5/   9] Loss:  1.44e-03
# [Epoch   98/ 100] [Batch    6/   9] Loss:  1.65e-03
# [Epoch   98/ 100] [Batch    7/   9] Loss:  1.77e-03
# [Epoch   98/ 100] [Batch    8/   9] Loss:  1.74e-03
# [Epoch   98/ 100] [Batch    9/   9] Loss:  1.39e-03
# [Epoch   99/ 100] [Batch    1/   9] Loss:  1.74e-03
# [Epoch   99/ 100] [Batch    2/   9] Loss:  1.79e-03
# [Epoch   99/ 100] [Batch    3/   9] Loss:  1.29e-03
# [Epoch   99/ 100] [Batch    4/   9] Loss:  1.39e-03
# [Epoch   99/ 100] [Batch    5/   9] Loss:  1.78e-03
# [Epoch   99/ 100] [Batch    6/   9] Loss:  1.44e-03
# [Epoch   99/ 100] [Batch    7/   9] Loss:  1.82e-03
# [Epoch   99/ 100] [Batch    8/   9] Loss:  1.76e-03
# [Epoch   99/ 100] [Batch    9/   9] Loss:  1.46e-03
# [Epoch  100/ 100] [Batch    1/   9] Loss:  1.66e-03
# [Epoch  100/ 100] [Batch    2/   9] Loss:  1.66e-03
# [Epoch  100/ 100] [Batch    3/   9] Loss:  1.47e-03
# [Epoch  100/ 100] [Batch    4/   9] Loss:  1.65e-03
# [Epoch  100/ 100] [Batch    5/   9] Loss:  1.80e-03
# [Epoch  100/ 100] [Batch    6/   9] Loss:  1.50e-03
# [Epoch  100/ 100] [Batch    7/   9] Loss:  1.41e-03
# [Epoch  100/ 100] [Batch    8/   9] Loss:  1.71e-03
# [Epoch  100/ 100] [Batch    9/   9] Loss:  1.65e-03
# LinearModel(
#   (linear): Linear(in_features=1, out_features=1, bias=True)
# )

# %%
if input_dim == output_dim == 1:
    n_test = 500
    X_test = np.random.rand(n_test, input_dim)
    y_pred = []

    state_dict = model.state_dict()

    for idx in range(len(train_hist['weight'])):
        state_dict['linear.weight'] = torch.tensor([[train_hist['weight'][idx]]])
        state_dict['linear.bias'] = torch.tensor([train_hist['bias'][idx]])
        model.load_state_dict(state_dict)

        y_pred.append(model.forward(torch.tensor(X_test.astype('f'))).detach().numpy())

# %%
if input_dim == output_dim == 1:
    fig = plt.figure(figsize=(15, 5))
    fig.clf()

    ax = fig.add_subplot(1, 3, 1)
    levels = np.logspace(np.log(np.min(loss_values)), np.log(np.max(loss_values)), 20)
    ax.contourf(ww, bb, loss_values, levels=levels, norm=colors.LogNorm())
    ax.plot(train_hist['weight'], train_hist['bias'], '.-b')
    ax.plot(A[0], b, 'r*', markersize=10)
    ax.set_xlabel('weight')
    ax.set_ylabel('bias')
    # ax.legend(['optim', '(A, b)'])
    ax.grid(True)
    ax.set_xlim(-2, 2)
    ax.set_ylim(-2, 2)

    ax = fig.add_subplot(1, 3, 2)
    ax.loglog(np.abs(train_hist['loss']))
    ax.set_xlabel('Iter')
    ax.set_ylabel('Loss')
    ax.grid(True)

    ax = fig.add_subplot(1, 3, 3)
    ax.plot(X_train, y_train, '.')
    a = ax.plot(X_test, y_pred[0], '-', alpha=0.1)
    for y in y_pred[1:]:
        ax.plot(X_test, y, '-', alpha=0.1, color=a[0].get_color())
    ax.plot(X_test, y_pred[-1], 'k')
    ax.grid(True)

    fig.tight_layout()

else:
    fig = plt.figure()
    fig.clf()
    ax = fig.gca()
    ax.loglog(np.abs(train_hist['loss']))
    ax.set_xlabel('Iter')
    ax.set_ylabel('Loss')
    ax.grid(True)
